# %%
'''
탐색적 자료 분석 EDA(Exploratory Data Analysis)
- 데이터를 분석하기 전에 그래프나 통계적인 방법으로 데이터를 직관적으로 바라보는 과정
- 데이터를 있는 그대로 바라보는데 중점을 맞추어 데이터가 가지고 있는 의미를 다양한 각도로 바라보고 이해
- 목적
  1. 데이터 수집 의사를 결정
  2. 데이터 유형에 맞는 모델을 선택
  3. 변수들 사이의 관계를 파악

시각화 패키지
- Matplotlib: 가장 직관적으로 다양한 시각화 가능
- Seaborn: Matplotlib 보완, 짧은 코드로 시각화 가능
- Plotly: 인터랙티브한 그래프, 마우스를 오버했을 때 마우스 오버한 곳의 값을 보여주고, jsp에 적용 가능

그래프 시각화
- 히스토그램: 연속형 데이터의 분포
- 막대그래프: 범주형 데이터의 분포
- 박스플롯: 이상치를 판단하고 데이터가 어디에 치우쳐 있는지 파악
- QQplot: 샘플이 가정한 분포와 그래프가 얼마나 일치하는지 파악
- 산점도: 변수들의 관계, 밀집 위치 파악

이미지 시각화
- 픽셀: 2차원 벡터로 표현
- 색 공간: RGB, gray scale.. 
'''

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline 
# 주피터 내에서 아웃풋을 보여주겠다.

# %%
x = np.linspace(0, 10, 100)
x # 0부터 10까지 100개의 숫자
fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
plt.plot(x, np.tan(x), '--^')

# %%
fig.savefig('test.png')

# %%
from IPython.display import Image
Image('test.png')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpeg': 'Joint Photographic Experts Group',
#  'jpg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %%
#matplotlib의 기본 구성은 그림(figure)과 축(axes)

x = np.linspace(0, 10, 100)
y = x**2
y_ = x**3

plt.plot(x, y, '--')
plt.plot(x, y_)
plt.show()

# %%
'''
선 색상과 스타일

plt.plot(x, y, color='red')
plt.plot(x, y, color='r')
plt.plot(x, y, color='0.2')
plt.plot(x, y, color='#ff0000')


plt.plot(x, y, linestyle='solid') = 실선 '-'
plt.plot(x, y, linestyle='dashed') = 파선 '--'
plt.plot(x, y, linestyle='dashdot') = 1점 쇄선 '-.'
plt.plot(x, y, linestyle='dotted') = 점선 ':'
'''

# %%
value = pd.Series([1, 2, 3], [100, 200, 300])

# plt.plot(value, linestyle='--', color='red') Series는 X축과 Y축이 변경 됨
plt.plot(value, '--g')

# %%
'''
경계표현
- 자동으로 표현 but plt.xlim, plt.ylim으로 상세 조정 가능
- plt.axis([x축의 최소값, x축의 최대값, y축의 최소값, y축의 최대값])으로 한번에 조정 가능
'''

# %%
x = np.linspace(0, 10, 100)
y = x**2

plt.plot(x, y, '-r')
# plt.xlim(-1, 11)
# plt.ylim(-10, 110)
# plt.axis([-1, 11, -10, 110])
# plt.axis('tight')
# plt.axis('equal')
plt.show()

# %%
'''
Label
- 축이름 달기

Legend
- 'best': 0
- 'upper right': 1
- 'upper left': 2
- 'lower left': 3
- 'lower right': 4
- 'right': 5
- 'center left': 6
- 'center right': 7
- 'lower center': 8
- 'upper center': 9
- 'center': 10

2  9  1
6  10  5, 7
3  8  4

'''

# %%
x = np.linspace(0, 10, 100)
y = x**2

plt.plot(x, y, '-r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = x**2
y_ = x**3

plt.plot(x, y, '-r', label='line1')
plt.plot(x, y_, '-b', label='line2')
# plt.xlabel('x')
# plt.ylabel('y')
plt.legend()
plt.show()

# %%
x = np.linspace(0, 10, 100)
y = x**2
y_ = x**3

plt.plot(x, y, '-r', label='line1')
plt.plot(x, y_, '-b', label='line2')

plt.legend(loc='upper center', bbox_to_anchor=(0, 0), ncol=3, fancybox=True, shadow=True)# bbox는 플롯 밖에 범례를 만듦
plt.show()

# %% [markdown]
# # Scatter(산점도)
# - 두 변수의 관계를 표현하는 방법
#
# - 양의 상관관계, 음의 상관관계
#
# - 군집: 점들의 모임

# %%
plt.scatter([10, 20], [10, 20], s=100, c=['r', 'b'],alpha=0.5) # alpha: 투명도
plt.show()

# %%
x = np.arange(0, 10)
y = x**2

plt.scatter(x, y, s=10, c='b', alpha=0.5)
plt.show()

# %%
import random

x = np.random.rand(50)
y = np.random.rand(50)
size = np.random.rand(50)*10000
colors = np.random.rand(50)

plt.scatter(x, y, s=size, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# #히스토그램
#
# - 히스토그램은 표로 되어 있는 도수 분포를 정보 그림으로 나타낸 것.
#
# - 막대그래프는 계급 즉 가로를 생각하지 않고 새로의 높이로만 나타냄.

# %%
arr = [np.random.randint(1, 7) for i in range(10)]
arr
# Out:
# [2, 3, 3, 2, 3, 1, 2, 4, 1, 6]

# %%
plt.grid(True)
plt.hist(arr)
plt.show()

# %%
arr = [np.random.randint(1, 7) for i in range(10)]
plt.hist(arr, bins=6, alpha=0.5)  
plt.show()

# %%
'''
Basic Attributes

- alpha: 투명도
- logy: Y축 Log scaling
- kind: line, bar, barh, kde
- subplots: 여러 개의 plot 그리기
- legend: 범례
- xlim, ylim: X측과 Y축의 경계
- grid: 격자 표시
- title: 그래프의 제목 지정
- linewidth: 라인 넓이
- color: 색
- linestyle: 실선, 점선, 1점쇄선..
- marker: 마커 지정, 특정 값의 점을 찍어줌
- markerfacecolor: 마커 색
- markersize: 마커 크기
'''

# %%
x = np.linspace(0, 10, 10)
y = x**2

plt.plot(x, y, '--b', 
         linewidth=3, 
         marker='^', 
         markersize=10,
         markerfacecolor='g')

plt.show()

# %% [markdown]
# #Pie Chart

# %%
labels = ['one', 'two', 'three', 'four']
sizes = [10, 20, 30, 40]

plt.pie(sizes, labels=labels)
plt.show()

# %%
labels = ['one', 'two', 'three', 'four']
sizes = [10, 20, 30, 40]

plt.pie(sizes, labels=labels, shadow=True, startangle=90)
plt.show()

# %%
labels = ['one', 'two', 'three', 'four']
sizes = [10, 20, 60, 90]
explode = (0.1, 0.1, 0.1, 0.2)

plt.pie(sizes, labels=labels, shadow=True, startangle=90, explode=explode)
plt.show()

# %%
labels = ['one', 'two', 'three', 'four']
sizes = [10, 20, 60, 90]
explode = (0.1, 0.1, 0.1, 0.2)

plt.pie(sizes, labels=labels, shadow=True, startangle=90, explode=explode, autopct='%1.0f%%')
plt.show()

# %% [markdown]
# #Bar Chart

# %%
plt.bar(['one', 'two', 'three'], [10, 20, 30])
plt.show()

# %%
plt.bar(['one', 'two', 'three'], [10, 20, 30])
plt.title('Bar CHart', fontsize=15)
plt.xlabel('Items', fontsize=15)
plt.ylabel('Sales', fontsize=15)
plt.show()

# %%
plt.barh(['one', 'two', 'three'], [10, 20, 30])
plt.title('Bar CHart', fontsize=15)
plt.xlabel('Items', fontsize=15)
plt.ylabel('Sales', fontsize=15)
plt.show()

# %%
plt.bar(['one', 'two', 'three'], [10, 20, 30], color='r')
plt.bar(['one', 'two', 'three'], [20, 40, 60], color='b', alpha=0.5, bottom=[10, 20, 30])

plt.title('Bar CHart', fontsize=15)
plt.xlabel('Items', fontsize=15)
plt.ylabel('Sales', fontsize=15)

plt.legend(['One', 'Two'])
plt.show()

# %% [markdown]
# #SubPlot

# %%
x = np.linspace(0, 10, 20)
y = x**2

# %%
plt.subplot(231)
plt.plot(x, y, 'r')

plt.subplot(232)
plt.plot(x, y, 'g')

plt.subplot(233)
plt.plot(x, y, 'b')

plt.subplot(234)
plt.plot(x, y, 'r')

plt.subplot(235)
plt.plot(x, y, 'g')

plt.subplot(236)
plt.plot(x, y, 'b')

plt.show()

# %%
grid = plt.GridSpec(2, 3)

plt.subplot(grid[0, 0])
plt.plot(x, y, 'r')

plt.subplot(grid[0, 1:])
plt.plot(x, y, 'g')

plt.subplot(grid[1, :2])
plt.plot(x, y, 'r')

plt.subplot(grid[1, 2])
plt.plot(x, y, 'b')

plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(x, y, 'b')
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(x, y, 'b')
plt.text(1, 70, 'hello world')
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(x, y, 'b')
plt.text(1, 70, f'$\mu=100, \sigma=15$')
plt.show()

# %%
plt.figure(figsize=(10, 3))
plt.plot(x, y, 'b')
plt.annotate('Max Value', xy=(10, 100), xytext=(1, 70), arrowprops=dict(facecolor='black', shrink=0.05))
plt.show()

# %%
# 오차 막대

x = np.linspace(0, 10, 20)
y = x**2

dy = 10 # 오차

plt.errorbar(x, y, yerr=dy, fmt='.k', ecolor='r')
plt.show()

# %%
# 그룹 bar chart

labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x-width/2, men_means, width, label='Men')
rects2 = ax.bar(x+width/2, women_means, width, label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

def autolabel(rects):
  for rect in rects:
    height = rect.get_height()
    ax.annotate('{}'.format(height),
                xy=(rect.get_x() + rect.get_width()/2, height),
                xytext=(0, 3),
                textcoords='offset points',
                ha='center', va='bottom')
  
autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
# 상관도 분석

vegetables = ['cucmber', 'tomato', 'lettuce', 'asparagus', 'potato', 'wheat', 'barley']
farmers = ['Farmer Joe', 'Upland Bros', 'Smith Gardening', 'Agrifun', 'Organiculture', 'BioGoods Ltd', 'Cornylee Corp.']
harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])

fig, ax = plt.subplots()
im = ax.imshow(harvest)

ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))

ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')


for i in range(len(vegetables)):
  for j in range(len(farmers)):
    text = ax.text(j, i, harvest[i, j], ha='center', va='center', color='w')

ax.set_title('Harvest of local farmers (in tons/year)')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Seaborn

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

x = np.linspace(0, 10, 20)
y = x**2

plt.plot(x, y)
plt.show()

# %%
import seaborn as sns

x = np.linspace(0, 10, 20)
y = x**2

sns.set()

plt.plot(x, y)
plt.show()

# %%
tips = sns.load_dataset('tips')
sns.relplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', data=tips)
plt.show()

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', style='smoker', data=tips)
plt.show()

# %%
# sns.relplot(x='total_bill', y='tip', hue='size',size='size', data=tips)
sns.relplot(x='total_bill', y='tip', size='size', sizes=(1, 100), data=tips)
plt.show()

# %%
fmri = sns.load_dataset('fmri')
sns.relplot(x='timepoint', y='signal', hue='event', style='event',
            col='subject', col_wrap=5,
            height=3, aspect=.75, linewidth=2.5,
            kind='line', data=fmri.query("region == 'frontal'")) # col_wrap: row당 개수

plt.show()

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
f, ax = plt.subplots(figsize=(7, 3))
sns.countplot(y='deck', data=titanic, color='r')
plt.show()

# %%
sns.pairplot(titanic, hue='class')
plt.show()

# pairplot: seaborn에서 상관관계의 다차원 데이터 시각화 자료를 보여줌
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Plotly

# %%
import plotly.express as px

df = px.data.gapminder().query("country == 'Canada'")
df.head()
# Out:
#     country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 240  Canada  Americas  1952    68.75  14785584  11367.16112       CAN      124
# 241  Canada  Americas  1957    69.96  17010154  12489.95006       CAN      124
# 242  Canada  Americas  1962    71.30  18985849  13462.48555       CAN      124
# 243  Canada  Americas  1967    72.13  20819767  16076.58803       CAN      124
# 244  Canada  Americas  1972    72.88  22284500  18970.57086       CAN      124

# %%
fig = px.line(df, x='year', y='lifeExp', title='Life expectancy in Canada')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7cd5cb86-528a-41fb-9c2b-608b7272cb61" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7cd5cb86-528a-41fb-9c2b-608b7272cb61")) {
#                     Plotly.newPlot(
#                         '7cd5cb86-528a-41fb-9c2b-608b7272cb61',
# ...

# %%
x = np.arange(5)
y = x**2

fig = px.scatter(x=x, y=y)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="60d2dce7-e0a0-44ce-871d-535f2bbe266f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60d2dce7-e0a0-44ce-871d-535f2bbe266f")) {
#                     Plotly.newPlot(
#                         '60d2dce7-e0a0-44ce-871d-535f2bbe266f',
# ...

# %%
data_canada = px.data.gapminder().query("country=='Canada'")
fig = px.bar(data_canada, x='year', y='pop')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0b8a4f92-5a0e-4639-a7f2-2a3e8656e0fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0b8a4f92-5a0e-4639-a7f2-2a3e8656e0fe")) {
#                     Plotly.newPlot(
#                         '0b8a4f92-5a0e-4639-a7f2-2a3e8656e0fe',
# ...

# %%
fig = px.pie(values=[1, 2, 3])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="40517b45-096a-48e3-9fa6-add523840d45" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("40517b45-096a-48e3-9fa6-add523840d45")) {
#                     Plotly.newPlot(
#                         '40517b45-096a-48e3-9fa6-add523840d45',
# ...

# %%
import plotly.graph_objects as go

labels = ['Oxygen', 'Hydrogen', 'Carbon_Dioxide', 'Nitrogen']
values = [4500, 2500, 1053, 500]

fig = go.Figure(data=[go.Pie(labels=labels, values=values, pull=[0, 0, 0.2, 0])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4cd37c13-c39b-4cbe-8a5f-e8c34cba1a97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4cd37c13-c39b-4cbe-8a5f-e8c34cba1a97")) {
#                     Plotly.newPlot(
#                         '4cd37c13-c39b-4cbe-8a5f-e8c34cba1a97',
# ...

# %%
fig = go.Figure(go.Sunburst(
    labels = ['Eve', 'Cain', 'Seth', 'Enos', 'Noam', 'Abel', 'Awan', 'Enoch', 'Azura'],
    parents = ['', 'Eve', 'Eve', 'Seth', 'Seth', 'Eve', 'Eve', 'Awan', 'Eve'],
    values = [10, 14, 12, 10, 2, 6, 6, 4, 4]
))
fig.update_layout(margin = dict(t=0, l=0, r=0, b=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e19891e0-ec6d-4472-89c4-00da3ead6910" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e19891e0-ec6d-4472-89c4-00da3ead6910")) {
#                     Plotly.newPlot(
#                         'e19891e0-ec6d-4472-89c4-00da3ead6910',
# ...
